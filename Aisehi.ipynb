# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

data = pd.read_csv("NVIDIA_STOCK.csv")

df = data[["Date", "Volume"]]
df["Date"] = pd.to_datetime(df["Date"], dayfirst= True)
df.set_index("Date", inplace= True)
# Out:
# C:\Users\vineet\AppData\Local\Temp\ipykernel_39168\3732017453.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst= True)

# %%
df
# Out:
#                Volume
# Date
# 2018-01-02  355616000
# 2018-01-03  914704000
# 2018-01-04  583268000
# 2018-01-05  580124000
# 2018-01-08  881216000
# ...               ...
# 2024-09-24  354966800
# 2024-09-25  284692900
# 2024-09-26  302582900
# 2024-09-27  271009200
# 2024-09-30  226553700
#
# [1697 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
class Single:
    
    def __init__ (self, val, next = None):
        self.val = val
        self.next = next

# %%
myString = "Position of a character"
myString.find("x")
# Out:
# -1

# %%
def stringsplicer(s):
    s2 = ""
    for i in s:
        if s2.find(i) == -1:
            s2 = s2 + i
        else:
            break;
    return s2

stringsplicer("abcabcbb")
# Out:
# 'abc'

# %% [markdown]
# The thing is that this works fine while making substring from start but you can also make substrings from other indices with similar conditions to actually find the longest substring.
# Hint says generate all possible substrings and then find the one with the maximum length.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dd = pd.read_csv("Nat_Gas.csv", parse_dates=True)
dd.set_index("Dates", inplace=True)

# %%
dd.head()
plt.figure(figsize=(16,8))
plt.xlabel("Year")
plt.ylabel("Prices")
plt.plot(dd)
plt.show()

# %%
from statsmodels.tsa.api import SimpleExpSmoothing
model = SimpleExpSmoothing(dd)
model_single_fit = model.fit()
forecast_single = model_single_fit.forecast(12)
ff = pd.DataFrame(forecast_single)
ff
# Out:
# c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:559: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   _index = to_datetime(index)
# c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
#                0
# 2024-10-31  11.8
# 2024-11-30  11.8
# 2024-12-31  11.8
# 2025-01-31  11.8
# 2025-02-28  11.8
# 2025-03-31  11.8
# 2025-04-30  11.8
# 2025-05-31  11.8
# 2025-06-30  11.8
# 2025-07-31  11.8
# 2025-08-31  11.8
# 2025-09-30  11.8

# %%
gg["Fitted Values"] = pd.DataFrame(model_single_fit.fittedvalues)
gg["OG"]  = dd['Prices']

gg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 gg["Fitted Values"] = pd.DataFrame(model_single_fit.fittedvalues)
#       2 gg["OG"]  = dd['Prices']
#       4 gg
#
# NameError: name 'gg' is not defined

# %%
plt.plot(dd, label = "Original Data")
plt.plot(model_single_fit.fittedvalues, label = "Fitted Values")
plt.plot(forecast_single, label = "Forecast")
plt.xlabel("Year")
plt.ylabel("Prices")
plt.title("Single Exponential Smoothing")
plt.legend()
plt.show()
# Out:
# C:\Users\vineet\AppData\Local\Temp\ipykernel_19504\2654902497.py:3: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   plt.plot(forecast_single, label = "Forecast")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 plt.plot(dd, label = "Original Data")
#       2 plt.plot(model_single_fit.fittedvalues, label = "Fitted Values")
# ----> 3 plt.plot(forecast_single, label = "Forecast")
#       4 plt.xlabel("Year")
#       5 plt.ylabel("Prices")
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# ...
