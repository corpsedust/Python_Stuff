# %%
import os
path = os.getcwd()
path
# Out:
# 'c:\\Users\\vineet\\Desktop\\TimeSeries\\houseprice'

# %%
with open(f"{path}hello.txt", 'wb') as f:
    f.write("There is a special place for you in hell")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 with open(f"{path}hello.txt", 'wb') as f:
# ----> 2     f.write("There is a special place for you in hell")
#
# TypeError: a bytes-like object is required, not 'str'
