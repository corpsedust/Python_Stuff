# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates

# %%
df = pd.read_csv("NVIDIA_STOCK.csv")
df.drop(["Adj Close", "Volume"], axis = 1, inplace = True)
df.head()
# Out:
#          Date    Close     High      Low     Open
# 0  02-01-2018  4.98375  4.98750  4.86250  4.89450
# 1  03-01-2018  5.31175  5.34250  5.09375  5.10250
# 2  04-01-2018  5.33975  5.45125  5.31725  5.39400
# 3  05-01-2018  5.38500  5.42275  5.27700  5.35475
# 4  08-01-2018  5.55000  5.62500  5.46450  5.51000

# %%
df = df.iloc[:,[0,4,2,3,1]]

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close
# 0  02-01-2018  4.89450  4.98750  4.86250  4.98375
# 1  03-01-2018  5.10250  5.34250  5.09375  5.31175
# 2  04-01-2018  5.39400  5.45125  5.31725  5.33975
# 3  05-01-2018  5.35475  5.42275  5.27700  5.38500
# 4  08-01-2018  5.51000  5.62500  5.46450  5.55000

# %%
df["Date"] = df["Date"].map(mdates.date2num)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df["Date"] = df["Date"].map(mdates.date2num)
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4700, in Series.map(self, arg, na_action)
#    4620 def map(
#    4621     self,
#    4622     arg: Callable | Mapping | Series,
#    4623     na_action: Literal["ignore"] | None = None,
#    4624 ) -> Series:
#    4625     """
#    4626     Map values of Series according to an input mapping or function.
#    4627
#    (...)
#    4698     dtype: object
#    4699     """
# -> 4700     new_values = self._map_values(arg, na_action=na_action)
#    4701     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702         self, method="map"
#    4703     )
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\dates.py:444, in date2num(d)
#     441 if not d.size:
#     442     # deals with an empty array...
#     443     return d
# --> 444 tzi = getattr(d[0], 'tzinfo', None)
#     445 if tzi is not None:
#     446     # make datetime naive:
#     447     d = [dt.astimezone(UTC).replace(tzinfo=None) for dt in d]
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
fig, ax = plt.subplots()
candlestick_ohlc(ax, df.values, width = 0.6, colorup = "g", colordown = "r")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 candlestick_ohlc(ax, df.values, width = 0.6, colorup = "g", colordown = "r")
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpl_finance.py:249, in candlestick_ohlc(ax, quotes, width, colorup, colordown, alpha)
#     215 def candlestick_ohlc(ax, quotes, width=0.2, colorup='k', colordown='r',
#     216                      alpha=1.0):
#     217     """
#     218     Plot the time, open, high, low, close as a vertical line ranging
#     219     from low to high.  Use a rectangular bar to represent the
#    (...)
#     247
#     248     """
# --> 249     return _candlestick(ax, quotes, width=width, colorup=colorup,
#     250                         colordown=colordown,
#     251                         alpha=alpha, ochl=False)
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpl_finance.py:317, in _candlestick(ax, quotes, width, colorup, colordown, alpha, ochl)
#     307     height = open - close
#     309 vline = Line2D(
#     310     xdata=(t, t), ydata=(low, high),
#     311     color=color,
#     312     linewidth=0.5,
#     313     antialiased=True,
#     314 )
#     316 rect = Rectangle(
# --> 317     xy=(t - OFFSET, lower),
#     318     width=width,
#     319     height=height,
#     320     facecolor=color,
#     321     edgecolor=color,
#     322 )
#     323 rect.set_alpha(alpha)
#     325 lines.append(vline)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'
