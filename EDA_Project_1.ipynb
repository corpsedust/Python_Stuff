# %% [markdown]
# <h2 style = "text-align:center;color:#76CD26">EDA Project_1</h2>

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("C:\\Users\\vineet\\Desktop\\TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\vineet\AppData\Local\Temp\ipykernel_22744\2796490272.py:4: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\vineet\\Desktop\\TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
#df[df["Athlete gender"]== "F" && df["Athlete age category"] == "W60"]

df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#clean the data 

#Only want USA races, 50Km or 50Miles in 2020
#Show 50miles or 50K
#50k

df[df["Event distance/length"] == "50km"]
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#If some input as 50k

df[df["Event distance/length"] == "50k"]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
#50 miles
df[df["Event distance/length"] == "50m"]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
df[df["Event distance/length"] == "50mi"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Combine 50k and 50mi with isin

df[df["Event distance/length"].isin(["50km","50mi"])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Filtering 2020 data 

df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020)]

#for and condition to work you have put each condition in parenthesis
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df["Event name"] == "Everglades 50 Mile Ultra Run (USA)"]
# Out:
#          Year of event Event dates                          Event name  \
# 51923             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51924             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51925             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51926             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51927             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# ...                ...         ...                                 ...
# 6417091           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417092           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417093           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417094           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417095           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Now we have to figure out how to pull only USA data
df[df["Event name"] == "Everglades 50 Mile Ultra Run (USA)"]["Event name"]
# Out:
# 51923      Everglades 50 Mile Ultra Run (USA)
# 51924      Everglades 50 Mile Ultra Run (USA)
# 51925      Everglades 50 Mile Ultra Run (USA)
# 51926      Everglades 50 Mile Ultra Run (USA)
# 51927      Everglades 50 Mile Ultra Run (USA)
#                           ...
# 6417091    Everglades 50 Mile Ultra Run (USA)
# 6417092    Everglades 50 Mile Ultra Run (USA)
# 6417093    Everglades 50 Mile Ultra Run (USA)
# 6417094    Everglades 50 Mile Ultra Run (USA)
# 6417095    Everglades 50 Mile Ultra Run (USA)
# Name: Event name, Length: 338, dtype: object

# %%
df[df["Event name"] == "Everglades 50 Mile Ultra Run (USA)"]["Event name"].str.split("(")
# Out:
# 51923      [Everglades 50 Mile Ultra Run , USA)]
# 51924      [Everglades 50 Mile Ultra Run , USA)]
# 51925      [Everglades 50 Mile Ultra Run , USA)]
# 51926      [Everglades 50 Mile Ultra Run , USA)]
# 51927      [Everglades 50 Mile Ultra Run , USA)]
#                            ...
# 6417091    [Everglades 50 Mile Ultra Run , USA)]
# 6417092    [Everglades 50 Mile Ultra Run , USA)]
# 6417093    [Everglades 50 Mile Ultra Run , USA)]
# 6417094    [Everglades 50 Mile Ultra Run , USA)]
# 6417095    [Everglades 50 Mile Ultra Run , USA)]
# Name: Event name, Length: 338, dtype: object

# %%
df[df["Event name"] == "Everglades 50 Mile Ultra Run (USA)"]["Event name"].str.split("(").str.get(1)
# Out:
# 51923      USA)
# 51924      USA)
# 51925      USA)
# 51926      USA)
# 51927      USA)
#            ...
# 6417091    USA)
# 6417092    USA)
# 6417093    USA)
# 6417094    USA)
# 6417095    USA)
# Name: Event name, Length: 338, dtype: object

# %%
df[df["Event name"] == "Everglades 50 Mile Ultra Run (USA)"]["Event name"].str.split("(").str.get(1).str.split(")")
# Out:
# 51923      [USA, ]
# 51924      [USA, ]
# 51925      [USA, ]
# 51926      [USA, ]
# 51927      [USA, ]
#             ...
# 6417091    [USA, ]
# 6417092    [USA, ]
# 6417093    [USA, ]
# 6417094    [USA, ]
# 6417095    [USA, ]
# Name: Event name, Length: 338, dtype: object

# %%
df[df["Event name"] == "Everglades 50 Mile Ultra Run (USA)"]["Event name"].str.split("(").str.get(1).str.split(")").str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
#don't need Everglades anymore we just used it to get to code in line 39 
df[df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Combine all filters together

df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020) & (df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA")]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2 = df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020) & (df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA")]
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %%
#remove (USA) from event name

df2["Event name"].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df2["Event name"] = df2["Event name"].str.split('(').str.get(0)
# Out:
# C:\Users\vineet\AppData\Local\Temp\ipykernel_22744\9866251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Event name"] = df2["Event name"].str.split('(').str.get(0)

# %%
df2.head(5)
#USA gone
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
#Cleaning up the athlete age category
#Changing the Age category from current to Year of event - Athlete birth year

df2['athlete_age'] = 2020 - df2["Athlete year of birth"]

df2
# Out:
# C:\Users\vineet\AppData\Local\Temp\ipykernel_22744\6940529.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['athlete_age'] = 2020 - df2["Athlete year of birth"]
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# ...

# %%
df2[(df2["Athlete age category"].isna())]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
df2["Athlete performance"] = df2["Athlete performance"].str.split(" ").str.get(0)
df2
# Out:
# C:\Users\vineet\AppData\Local\Temp\ipykernel_22744\4192972396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete performance"] = df2["Athlete performance"].str.split(" ").str.get(0)
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...

# %%
df2 = df2.drop(["Athlete club","Athlete country","Athlete year of birth","Athlete age category"], axis = 1)

# %%
df2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
#clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# athlete_age                  233
# dtype: int64

# %%
df2[df2['athlete_age'].isna() == 1]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2 = df2.dropna()

# %%
df2.shape
# Out:
# (25857, 10)

# %%
#check for dupes
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
#reset index
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#fix types
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# athlete_age                  float64
# dtype: object

# %%
#change athlete_age data type to integer
df2["athlete_age"] = df2["athlete_age"].astype(int)
# Out:
# C:\Users\vineet\AppData\Local\Temp\ipykernel_22744\492844353.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["athlete_age"] = df2["athlete_age"].astype(int)

# %%
df2["Athlete average speed"] = df2["Athlete average speed"].astype(float)
# Out:
# C:\Users\vineet\AppData\Local\Temp\ipykernel_22744\1434159826.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete average speed"] = df2["Athlete average speed"].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
df2
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...                ...         ...                                       ...
# 2760957           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
# ...

# %%
df2.reset_index(drop = True, inplace=True)

# %%
#Rename columns
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

#Changing column names for convenience
#converting everything to lower case, removing spaces
#making names shorter - It's easier to write code later

# %%
df2 = df2.rename(columns = {"Year of event":"year" ,"Event dates": "race_day","Event name":"race_name","Event distance/length" : "race_length", "Event number of finishers":"race_number_of_finishers",
                            "Athlete performance":"athlete_performane","Athlete gender":"athlete_gender", "Athlete average speed":"athlete_average_speed","Athlete ID":"athlete_id"})

# %%
df2.rename(columns = {"athlete_performane":"athlete_performance"}, inplace=True)
df2.head()
# Out:
#    year    race_day                                 race_name race_length  \
# 0  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4  2020  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#    race_number_of_finishers athlete_performance athlete_gender  \
# 0                        20             3:17:55              M
# 1                        20             4:02:32              M
# 2                        20             4:07:57              M
# 3                        20             4:22:02              M
# 4                        20             4:27:34              M
#
#    athlete_average_speed  athlete_id  athlete_age
# 0                 15.158       71287           29
# ...

# %%
#reorder columns

df3 = df2[["race_day", "race_name", "race_length", "race_number_of_finishers", "athlete_id","athlete_gender", "athlete_age","athlete_performance","athlete_average_speed"]]
df3
# Out:
#          race_day                                 race_name race_length  \
# 0      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...           ...                                       ...         ...
# 25852  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25853  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25854  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25855  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25856  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# ...

# %%
#find the 2 races that Ryan ran - Sarasota | Everglades

# %%
df3[df3["race_name"] == "Everglades 50 Mile Ultra Run "]
# Out:
#         race_day                      race_name race_length  \
# 7081  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7082  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7083  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7084  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7085  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7086  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7087  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7088  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7089  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7090  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7091  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7092  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7093  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7094  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 7095  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# ...

# %%
#Ryan's time was 9:19:10, looking at the table we find athlete id to be 222509
#df3[df3["athlete_id"]  == 222509]

df3
# Out:
#          race_day                                 race_name race_length  \
# 0      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...           ...                                       ...         ...
# 25852  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25853  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25854  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25855  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25856  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# ...

# %%
#charts and graphs

sns.histplot(df3["race_length"])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %% [markdown]
# A lot more 50kms races than 50miles.

# %%
#males vs females

sns.histplot(df3, x = "race_length", hue = "athlete_gender")
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %% [markdown]
# M to F ratio is higher in 50 miles as  compared to 50km, which seesm almost equal

# %%
sns.displot(df3[df3['race_length'] == "50mi"]['athlete_average_speed'])

# %% [markdown]
# Average speed is around 6.

# %%
sns.displot(df3[df3['race_length'] == "50km"]['athlete_average_speed'])

# %%
sns.violinplot(data = df3, x = 'race_length', y = 'athlete_average_speed', hue ="athlete_gender", split = True, inner = "quart", linewidth = 1)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %% [markdown]
# The dotted lines indicate how far or close the distribution is. For 50Km in general makes are faster than females but in 50miles females and males are almost close.
# For shorter races males will be faster but longer races kinda equalizes both the gender.

# %%
sns.lmplot(data = df3, x = "athlete_age", y = "athlete_average_speed",hue = "athlete_gender" )

# %% [markdown]
# General decline in athlete average speed with age,makes sense.
# On average Females are slower than males.

# %% [markdown]
# <h3 style = "text-align:center;">Plotting the scatter plot separately for 50miles and 50kms</h3>

# %%
df4 = df3[df3["race_length"] == "50km"]
df4
# Out:
#          race_day                                 race_name race_length  \
# 0      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...           ...                                       ...         ...
# 25852  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25853  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25854  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25855  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25856  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# ...

# %%
sns.lmplot(data = df4, x = "athlete_age", y = "athlete_average_speed",hue = "athlete_gender" )

# %%
df5 = df3[df3["race_length"] == "50mi"]
sns.lmplot(data = df5, x = "athlete_age", y = "athlete_average_speed",hue = "athlete_gender" )

# %% [markdown]
# <font color = "pink">Some conclusions:</font>
# - less data points in 50miles as indicated by the histogram plot.
# - male and female average speed graphs slowly get closer with age
# - graph get closer at a much faster rate in 50miles

# %% [markdown]
# <h3 style = "text-align:center;color:#00A86B">Asking questions and finding answers in the dataset</h3>

# %% [markdown]
# Some EDA questions that can be explored with the given dataset:
#
# 1. **General Statistics:**
#     - What is the distribution of event distances (e.g., 50km, 50mi)?
#     - What is the distribution of athlete genders across different event distances?
#
# 2. **Performance Analysis:**
#     - What is the average performance time for different event distances?
#     - How does the average performance time vary by gender for different event distances?
#
# 3. **Age Analysis:**
#     - What is the distribution of athlete ages across different event distances?
#     - How does athlete performance vary with age for different event distances?
#     - Is there a significant difference in performance between different age categories?
#
# 4. **Country Analysis:**
#     - Which countries have the most participants in the dataset?
#     - How does the average performance time vary by country?
#
# 5. **Yearly Trends:**
#     - How has the number of events and participants changed over the years?
#     - Are there any noticeable trends in performance times over the years?
#
# 6. **Gender Comparison:**
#     - How does the performance of male and female athletes compare across different event distances?
#     - Are there any significant differences in the average speed of male and female athletes?
#
# 7. **Event-Specific Analysis:**
#     - Which events have the highest number of finishers?
#     - What are the top events in terms of average athlete performance?
#
# 8. **Speed Analysis:**
#     - What is the distribution of average speeds for different event distances?
#     - How does the average speed vary by gender and age?
#
# 9. **Club Analysis:**
#     - Which athlete clubs have the most participants?
#     - How does the performance of athletes from different clubs compare?
#
# 10. **Missing Data:**
#      - How much missing data is there in each column?
#      - How does the presence of missing data affect the analysis?
#
# These questions can help guide your exploratory data analysis and uncover interesting insights from the dataset.

# %%
#Difference in speed for the 50k, 50mi male to female

# %%
df3.groupby(["race_length", "athlete_gender"])["athlete_average_speed"].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 7.083011
#              M                 7.738985
# 50mi         F                 6.834371
#              M                 7.257633
# Name: athlete_average_speed, dtype: float64

# %%
#What age groups are the best in the 50m Race (20 + race minimum)

df3.query("race_length == '50mi'").groupby("athlete_age")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean", ascending = False).query("count > 19").head(15)
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182

# %% [markdown]
# <h3 style = "text-align : center">Trying to understand wtf happened above?</h3>

# %%
df3.query("race_length == '50mi'")
# Out:
#          race_day                   race_name race_length  \
# 433    01.02.2020  Elephant Mountain 50 Mile         50mi
# 434    01.02.2020  Elephant Mountain 50 Mile         50mi
# 435    01.02.2020  Elephant Mountain 50 Mile         50mi
# 436    01.02.2020  Elephant Mountain 50 Mile         50mi
# 437    01.02.2020  Elephant Mountain 50 Mile         50mi
# ...           ...                         ...         ...
# 25613  10.10.2020  Old Cascadia 50 Mile Race         50mi
# 25614  10.10.2020  Old Cascadia 50 Mile Race         50mi
# 25615  10.10.2020  Old Cascadia 50 Mile Race         50mi
# 25616  10.10.2020  Old Cascadia 50 Mile Race         50mi
# 25617  10.10.2020  Old Cascadia 50 Mile Race         50mi
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 433                          10       86674              M           33
# 434                          10       53268              M           35
# ...

# %%
#first filter out the 50 milers
#then group by age and calculate average speed for each age bracket

df3.query("race_length == '50mi'").groupby("athlete_age")["athlete_average_speed"].agg(["mean","count"])
# Out:
#                  mean  count
# athlete_age
# 12           10.28000      1
# 13            6.19800      1
# 14            5.90800      2
# 15            8.40600      1
# 16            6.65540      5
# ...               ...    ...
# 71            6.17325      4
# 72            5.85850      8
# 73            5.82375      4
# 74            6.27000      1
# 79            5.96900      4
#
# [64 rows x 2 columns]

# %%
#now sorting the above data by mean - we want highest speed first so ascending = false
df3.query("race_length == '50mi'").groupby("athlete_age")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean",ascending= False)
# Out:
#                   mean  count
# athlete_age
# 12           10.280000      1
# 15            8.406000      1
# 29            7.902252    135
# 23            7.779800     55
# 28            7.575252    107
# ...                ...    ...
# 65            5.934786     14
# 14            5.908000      2
# 72            5.858500      8
# 73            5.823750      4
# 70            5.470667     12
#
# [64 rows x 2 columns]

# %%
#Now only filtering out the data for age ranges where number of races are >19

df3.query("race_length == '50mi'").groupby("athlete_age")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean",ascending= False).query("count > 19").head(15)
# Out:
#                  mean  count
# athlete_age
# 29           7.902252    135
# 23           7.779800     55
# 28           7.575252    107
# 30           7.569204    157
# 25           7.540923     91
# 31           7.451638    138
# 38           7.430022    231
# 35           7.422359    195
# 36           7.403854    185
# 26           7.379800     75
# 33           7.379188    149
# 22           7.367902     41
# 24           7.354274     73
# 42           7.327656    209
# 34           7.319011    182

# %%
#What age groups are the best in the 50m Race (20 + race minimum)
df3.query("race_length == '50mi'").groupby("athlete_age")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean",ascending= True).query("count > 9").head(15)
# Out:
#                  mean  count
# athlete_age
# 70           5.470667     12
# 65           5.934786     14
# 68           5.957500     10
# 67           6.114909     11
# 66           6.194300     10
# 60           6.261788     33
# 62           6.272730     37
# 61           6.358355     31
# 63           6.514806     31
# 58           6.582328     67
# 64           6.620727     22
# 50           6.671541    172
# 59           6.672072     83
# 48           6.696853    136
# 56           6.708373     67

# %%
#Seasons for the data -> Slower in summer than winter?

#spring 3-5
#Summer 6-8
#fall 9-11
#winter 12-2

#split between two decimals

# %% [markdown]
# <h3 style = "text-align : center;color: green">Me trying out an approach to the above statement (Random bullshit go brr)</h3>

# %%
dfs = df3
df3.head(5)
# Out:
#      race_day                                 race_name race_length  \
# 0  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#    race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 0                        20       71287              M           29
# 1                        20      629508              M           39
# 2                        20       64838              M           21
# 3                        20      704450              M           37
# 4                        20      810281              M           43
#
#   athlete_performance  athlete_average_speed
# 0             3:17:55                 15.158
# 1             4:02:32                 12.369
# ...

# %%
df3["race_day"].str.split(".")
# Out:
# 0        [02, 02, 2020]
# 1        [02, 02, 2020]
# 2        [02, 02, 2020]
# 3        [02, 02, 2020]
# 4        [02, 02, 2020]
#               ...
# 25852    [03, 10, 2020]
# 25853    [03, 10, 2020]
# 25854    [03, 10, 2020]
# 25855    [03, 10, 2020]
# 25856    [03, 10, 2020]
# Name: race_day, Length: 25857, dtype: object

# %%
df3["race_month"] = df3["race_day"].str.split(".").str.get(1).astype(int)
df3.head()
# Out:
#      race_day                                 race_name race_length  \
# 0  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#    race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 0                        20       71287              M           29
# 1                        20      629508              M           39
# 2                        20       64838              M           21
# 3                        20      704450              M           37
# 4                        20      810281              M           43
#
#   athlete_performance  athlete_average_speed  race_month
# 0             3:17:55                 15.158           2
# ...

# %%
df3.query("race_month < 0")
# Out:
#              race_day                            race_name race_length  \
# 2254   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# 2255   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# 2256   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# 2257   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# 2258   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# ...               ...                                  ...         ...
# 25465  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
# 25466  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
# 25467  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
# 25468  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
# 25469  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# ...

# %%
df3.groupby("race_month")["athlete_average_speed"].mean()
# Out:
# race_month
# -29    7.191182
# -28    6.404824
# -27    7.380826
# -26    8.089958
# -25    5.910957
# -23    5.530919
# -21    6.213029
# -20    6.028718
# -19    6.920625
# -18    5.970455
# -16    5.646347
# -15    7.846161
# -14    6.586241
# -13    8.811265
# -11    6.824688
# -9     6.529357
# -8     6.913214
# -7     8.277714
# -6     6.299129
#  1     7.632473
#  2     7.675145
#  3     7.806742
#  5     5.850947
#  6     6.639615
#  7     6.845081
#  8     7.016572
#  9     7.262929
#  10    7.405003
#  11    7.483958
#  12    7.408109
# Name: athlete_average_speed, dtype: float64

# %%
df3.head()
# Out:
#      race_day                                 race_name race_length  \
# 0  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4  02.02.2020  West Seattle Beach Run - Winter Edition         50km
#
#    race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 0                        20       71287              M           29
# 1                        20      629508              M           39
# 2                        20       64838              M           21
# 3                        20      704450              M           37
# 4                        20      810281              M           43
#
#   athlete_performance  athlete_average_speed  race_month
# 0             3:17:55                 15.158           2
# ...

# %%
df3.drop("race_month", axis=1)
# Out:
#          race_day                                 race_name race_length  \
# 0      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...           ...                                       ...         ...
# 25852  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25853  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25854  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25855  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25856  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# ...

# %%
#Dates are in the format, 02.02.2020 and 18.-19.01.2020, I want to extract month value from both
#ChatGPT solution 

regex_mm_dd_yyyy = r'\b\d{2}\.(\d{2})\.\d{4}\b'       # For MM.DD.YYYY
regex_dd_range_mm_yyyy = r'\b\d{2}\.-\d{2}\.(\d{2})\.\d{4}\b'  # For DD.-DD.MM.YYYY

df3['race_month'] = (df3['race_day'].str.extract(f'{regex_mm_dd_yyyy}|{regex_dd_range_mm_yyyy}').bfill(axis=1)[0])  # Fill from the left (in case one regex matches)
df3
# Out:
#          race_day                                 race_name race_length  \
# 0      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4      02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...           ...                                       ...         ...
# 25852  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25853  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25854  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25855  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
# 25856  03.10.2020   Yankee Springs Fall Trail Run Festival         50km
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# ...

# %%
#spring 3-5
#Summer 6-8
#fall 9-11
#winter 12-2
dfn = pd.DataFrame(df3.groupby("race_month")["athlete_average_speed"].mean())
dfn
# Out:
#             athlete_average_speed
# race_month
# 01                       7.629795
# 02                       7.640211
# 03                       7.807734
# 05                       5.850947
# 06                       6.691921
# 07                       6.845081
# 08                       6.903904
# 09                       7.162728
# 10                       7.374881
# 11                       7.484297
# 12                       7.347077

# %%
dfn["months"] = dfn.index
dfn
# Out:
#             athlete_average_speed months
# race_month
# 01                       7.629795     01
# 02                       7.640211     02
# 03                       7.807734     03
# 05                       5.850947     05
# 06                       6.691921     06
# 07                       6.845081     07
# 08                       6.903904     08
# 09                       7.162728     09
# 10                       7.374881     10
# 11                       7.484297     11
# 12                       7.347077     12

# %%
spring = dfn.iloc[2:4]["athlete_average_speed"].mean()
summer = dfn.iloc[4:7]["athlete_average_speed"].mean()
autumn = dfn.iloc[7:10]["athlete_average_speed"].mean()
winter = dfn.iloc[[0,1,10]]["athlete_average_speed"].mean()

# %%
print(float(spring))
print(float(summer))
print(float(autumn))
print(float(winter))
# Out:
# 6.829340210869351
# 6.813635523940211
# 7.340635185553547
# 7.539027601176877

# %%
#clearly my genius is unmatched - from numbers we can say it's easier to run in winters than in summers

# %% [markdown]
# <h3 style = "text-align : center;color: green">Actual solution</h3>

# %%
dfq=df3
dfq["race_month"] = dfq["race_day"].str.split(".").str.get(1).astype(int)
dfq.head(25)
# Out:
#       race_day                                 race_name race_length  \
# 0   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 5   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 6   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 7   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 8   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 9   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 10  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 11  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 12  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...

# %%
dfq["race_season"] = dfq["race_month"].apply(lambda x: "Winter" if x > 11 else "Fall" if x > 8 else "Summer" if x > 5 else "Spring" if x > 2 else "Winter")

# %%
dfq.head(25)
# Out:
#       race_day                                 race_name race_length  \
# 0   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 1   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 2   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 3   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 4   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 5   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 6   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 7   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 8   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 9   02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 10  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 11  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# 12  02.02.2020  West Seattle Beach Run - Winter Edition         50km
# ...

# %%
#dfq.tail(50)

# %%
#is he not getting negative value for race month??
dfq.query("race_month < 0")
# Out:
#              race_day                            race_name race_length  \
# 2254   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# 2255   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# 2256   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# 2257   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# 2258   18.-19.01.2020  Celtic Winter Classic 50 Miles Run         50mi
# ...               ...                                  ...         ...
# 25465  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
# 25466  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
# 25467  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
# 25468  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
# 25469  10.-11.10.2020            Tesla Hertz Run 50 Miles         50mi
#
#        race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# ...

# %%
#see he is also getting -ve values so his analysis will not be accurate
#ANYWAYS

dfq.groupby("race_season")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean", ascending = False)
# spring: 6.829340210869351
# summer: 6.813635523940211
# autumn: 7.340635185553547
# winter: 7.539027601176877
# Out:
#                  mean  count
# race_season
# Spring       7.684430   3294
# Winter       7.518187  11595
# Fall         7.406619   8315
# Summer       6.869336   2653

# %%
#50 miler only

dfq.query('race_length == "50mi"').groupby("race_season")["athlete_average_speed"].agg(["mean","count"]).sort_values("mean", ascending = False)
# Out:
#                  mean  count
# race_season
# Fall         7.511585   1997
# Spring       7.082557    836
# Winter       7.048442   1977
# Summer       6.505776    817

# %% [markdown]
# - `pd.DataFrame()`: Creates a DataFrame object from a dictionary or other data structure.
# - `df.head()`: Returns the first n rows of the DataFrame.
# - `df.shape`: Returns the dimensions of the DataFrame.
# - `df.dtypes`: Returns the data types of each column in the DataFrame.
# - `df.isin()`: Filters the DataFrame based on whether elements are in a list of values.
# - `df[(condition)]`: Filters the DataFrame based on a condition.
# - `df.str.split()`: Splits strings in a column based on a delimiter.
# - `df.str.get()`: Retrieves elements at specified positions from each string in a column.
# - `df.drop()`: Removes specified labels from rows or columns.
# - `df.dropna()`: Removes missing values from the DataFrame.
# - `df.duplicated()`: Identifies duplicate rows in the DataFrame.
# - `df.reset_index()`: Resets the index of the DataFrame.
# - `df.astype()`: Casts a pandas object to a specified data type.
# - `df.rename()`: Renames columns or index labels.
# - `df.groupby()`: Groups the DataFrame using a mapper or by a Series of columns.
# - `df.agg()`: Aggregates data based on specified functions.
# - `df.sort_values()`: Sorts the DataFrame by the values of one or more columns.
# - `df.query()`: Queries the DataFrame using a boolean expression.
# - `df.bfill()`: Backward fills missing values in the DataFrame.
# - `df.memory_usage()`: Returns the memory usage of each column in the DataFrame.
# - `df.isna()`: Detects missing values in the DataFrame.
# - `df.sum()`: Returns the sum of the values for the requested axis.
# - `df.count()`: Returns the number of non-null values in the DataFrame.
# - `df.mean()`: Returns the mean of the values for the requested axis.
# - `df.apply()`: Applies a function along an axis of the DataFrame.
# - `df.extract()`: Extracts capture groups in the regex pat as columns in a DataFrame.
# - `sns.histplot()`: Plots a histogram using seaborn.
# - `sns.displot()`: Plots a distribution plot using seaborn.
# - `sns.violinplot()`: Plots a violin plot using seaborn.
# - `sns.lmplot()`: Plots a linear model plot using seaborn.

# %% [markdown]
# <h3 style = "text-align:center;color:#FFE5B4">My_Chicanery</h3>

# %%
#just checking how many entries before 1850
df[df["Year of event"] <= 1850]
# Out:
#          Year of event        Event dates                     Event name  \
# 6824328           1798         00.08.1798              14 h London (GBR)
# 6824329           1800         00.11.1800             64 miles Ury (GBR)
# 6824330           1801         02.12.1801          Thirsk 51 miles (GBR)
# 6824331           1801         10.11.1801            90 miles Hull (GBR)
# 6824332           1801         00.11.1801          Thirsk 50 miles (GBR)
# 6824333           1801         00.11.1801          Thirsk 50 miles (GBR)
# 6824334           1802         00.07.1802          64 miles London (GBR)
# 6824335           1805         00.07.1805          64 mlles London (GBR)
# 6824336           1807     12.-13.10.1807           24 h Newmarket (GBR)
# 6824337           1807     12.-13.10.1807           24 h Newmarket (GBR)
# 6824338           1809  01.06.-12.07.1809     1000 miles Newmarket (GBR)
# 6824339           1837         30.01.1837  London to Brighton Race (GBR)
#
# ...

# %%
#First female athlete record ???
df[df["Athlete gender"] == "F"]
#Last entry should be the first Female entry
# Out:
#          Year of event Event dates                        Event name  \
# 6                 2018  06.01.2018               Selva Costera (CHI)
# 7                 2018  06.01.2018               Selva Costera (CHI)
# 12                2018  06.01.2018               Selva Costera (CHI)
# 17                2018  06.01.2018               Selva Costera (CHI)
# 18                2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461187           1995  00.00.1995   Supermaraton Zagreb-Cazma (CRO)
# 7461191           1995  00.00.1995         La SainteLyon 65 km (FRA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df.tail(5)
# Out:
#          Year of event Event dates                                Event name  \
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 7461190                  65km                          2           4:33:20 h
# 7461191                  65km                          2           6:05:15 h
# 7461192                   24h                          3          241.000 km
# 7461193                   24h                          3          228.000 km
# 7461194                   24h                          3          224.000 km
#
# ...

# %%
#From chatGPT

(df == "F").stack().idxmax()
#This is counting from top, also records are not sorted so I can't rely on 
#first occurence from top or bottom - both are going to be wrong
# Out:
# (6, 'Athlete gender')

# %%
#Create a separate DF for female athletes, and then find the earliest record
df_w = df[df["Athlete gender"] == "F"]
df_w["Year of event"].min()
# Out:
# np.int64(1876)

# %%
df_w[df_w["Year of event"] == 1876]
# Out:
#          Year of event        Event dates                Event name  \
# 6824381           1876  30.06.-01.07.1876  100 miles Auckland (NZL)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 6824381                 100mi                          1          23:50:00 h
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 6824381          NaN             GBR                 1853.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 6824381                  W23                6752.0     1520524

# %%
#indian records
df[df["Athlete country"]=="IND" ]["Year of event"].min()
# Out:
# np.int64(1951)

# %% [markdown]
# 1. **General Statistics:**
#     - What is the distribution of event distances (e.g., 50km, 50mi)?
#     - What is the distribution of athlete genders across different event distances?

# %%
df
# Out:
#          Year of event Event dates                                Event name  \
# 0                 2018  06.01.2018                       Selva Costera (CHI)
# 1                 2018  06.01.2018                       Selva Costera (CHI)
# 2                 2018  06.01.2018                       Selva Costera (CHI)
# 3                 2018  06.01.2018                       Selva Costera (CHI)
# 4                 2018  06.01.2018                       Selva Costera (CHI)
# ...                ...         ...                                       ...
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
# ...

# %%
dfc =pd.DataFrame(df.groupby("Event distance/length")["Athlete gender"].count())
dfc
# Out:
#                        Athlete gender
# Event distance/length
# 07:35                              10
# 08:50h                              3
# 100.0km                            20
# 100.1km                           669
# 100.2km                             8
# ...                               ...
# 99km                             1100
# 99km/3Etappen                      95
# 99mi                               39
# 9:11h                             327
# 9h                               1246
#
# [2159 rows x 1 columns]

# %%
len(s)
# Out:
# 2160

# %% [markdown]
# ### Objective : Plot a graph of M vs F across different types of races
